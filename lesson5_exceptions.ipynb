# %% [markdown]
# ## Exceptions

# %% [markdown]
# ![texte](https://s1.o7planning.com/ru/11421/images/7601427.png)

# %% [markdown]
# ### To work with exceptions you'll need to use `try-except` construction

# %%
try:
    a = int(input())
except:
    raise ValueError('Wrong input, it should be a number')
# Out:
# dfv
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13692/1124290850.py in <module>
#       1 try:
# ----> 2     a = int(input())
#       3 except:
#
# ValueError: invalid literal for int() with base 10: 'dfv'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13692/1124290850.py in <module>
#       2     a = int(input())
#       3 except:
# ----> 4     raise ValueError('Wrong input, it should be a number')
#
# ValueError: Wrong input, it should be a number

# %%
def second():
    print('start second')
    1/0
    print('finish second')

def first():
    print('start first')
    second()
    print('finish first')
    
print('hello')
first()
# Out:
# hello
# start first
# start second
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13692/3064222101.py in <module>
#      10
#      11 print('hello')
# ---> 12 first()
#
# ~\AppData\Local\Temp/ipykernel_13692/3064222101.py in first()
#       6 def first():
#       7     print('start first')
# ----> 8     second()
#       9     print('finish first')
#      10
#
# ~\AppData\Local\Temp/ipykernel_13692/3064222101.py in second()
#       1 def second():
#       2     print('start second')
# ----> 3     1/0
#       4     print('finish second')
#       5
#
# ZeroDivisionError: division by zero

# %% [markdown]
# 3 ссылки на исключение.

# %% [markdown]
# ## Try-except

# %%
1/0
a + b
int('hello')
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13692/1490539976.py in <module>
# ----> 1 1/0
#       2 a + b
#       3 int('hello')
#
# ZeroDivisionError: division by zero

# %%
int('hello')
1/0
a + b
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13692/2519720648.py in <module>
# ----> 1 int('hello')
#       2 1/0
#       3 a + b
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %%
try:
    int('hello')
    print('sad mood')
    1/0
    a+b
except ValueError:
    print('error ValueError')
# Out:
# error ValueError

# %%
try:
    1/0
    int('hello')
    print('sad mood')
    a+b
except ValueError:
    print('error ValueError')
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13692/3971305215.py in <module>
#       1 try:
# ----> 2     1/0
#       3     int('hello')
#       4     print('sad mood')
#       5     a+b
#
# ZeroDivisionError: division by zero

# %%
try:
    print('sad mood')
    1/0
    int('hello')
    a+b
except ValueError:
    print('error ValueError')
except ZeroDivisionError:
    print('error ZeroDivisionError')
except NameError:
    print('error NameError')
# Out:
# sad mood
# error ZeroDivisionError

# %%
s = 'hello'
d = {}

try:
    d['key']
except Exception:
    print('error')
# Out:
# error

# %% [markdown]
# Можно вообще все виды ошибок включать
#
# ### Finally, Else

# %%
s = 'hello'
d = {}

try:
    d['key']
except Exception:
    print('error')
finally:
    print('end')
# Out:
# error
# end

# %%
try:
    1 / 0 
except (KeyError, IndexError):
    print('LookupError')
except ZeroDivisionError:
    print('error ZeroDivisionError')
else:
    print('Good')
finally:
    print('end')
# Out:
# error ZeroDivisionError
# end

# %% [markdown]
# Если исключение не сработало, то сработает `else`. `Finally` всегда сработает

# %% [markdown]
# ### Raise

# %%
try:
    {}['k']
except (KeyError, IndexError) as error:
    print('LookupError')
    print(f'Logging error: {error} {repr(error)}')
except ZeroDivisionError as err:
    print('error ZeroDivisionError')
    print(f'Logging error: {err} {repr(err)}')
# Out:
# LookupError
# Logging error: 'k' KeyError('k')

# %%
er = Exception('Big error')
raise er
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13692/4174638997.py in <module>
#       1 er = Exception('Big error')
# ----> 2 raise er
#
# Exception: Big error

# %%
try:
    [1,2,3][15]
except (KeyError, IndexError) as error:
    print(f'Logging error: {error} {repr(error)}')
    raise TypeError('ошибка типа') from None
except ZeroDivisionError as err:
    print('error ZeroDivisionError')
    print(f'Logging error: {err} {repr(err)}')
# Out:
# Logging error: list index out of range IndexError('list index out of range')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13692/3871049093.py in <module>
#       3 except (KeyError, IndexError) as error:
#       4     print(f'Logging error: {error} {repr(error)}')
# ----> 5     raise TypeError('ошибка типа') from None
#       6 except ZeroDivisionError as err:
#       7     print('error ZeroDivisionError')
#
# TypeError: ошибка типа

# %%
try:
    raise ValueError('ошибка значения')
except ValueError as first:
    try:
        raise TypeError('ошибка типа')
    except TypeError as second:
        raise Exception('Большое исключение') from None
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13692/4255706810.py in <module>
#       5         raise TypeError('ошибка типа')
#       6     except TypeError as second:
# ----> 7         raise Exception('Большое исключение') from None
#
# Exception: Большое исключение

# %%
try:
    raise ValueError('ошибка значения')
except ValueError as first:
    try:
        raise TypeError('ошибка типа')
    except TypeError as second:
        raise Exception('Большое исключение') from first
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13692/104727743.py in <module>
#       1 try:
# ----> 2     raise ValueError('ошибка значения')
#       3 except ValueError as first:
#
# ValueError: ошибка значения
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13692/104727743.py in <module>
#       5         raise TypeError('ошибка типа')
#       6     except TypeError as second:
# ----> 7         raise Exception('Большое исключение') from first
#
# Exception: Большое исключение

# %%
try:
    raise ValueError('ошибка значения')
except ValueError as first:
    try:
        raise TypeError('ошибка типа')
    except TypeError as second:
        raise Exception('Большое исключение') from second
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13692/1282756228.py in <module>
#       1 try:
# ----> 2     raise ValueError('ошибка значения')
#       3 except ValueError as first:
#
# ValueError: ошибка значения
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13692/1282756228.py in <module>
#       4     try:
# ----> 5         raise TypeError('ошибка типа')
#       6     except TypeError as second:
#
# TypeError: ошибка типа
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13692/1282756228.py in <module>
#       5         raise TypeError('ошибка типа')
#       6     except TypeError as second:
# ----> 7         raise Exception('Большое исключение') from second
#
# Exception: Большое исключение
